# %% [markdown]
# # Ontogenetic Growth Model - Intake Rate & Hyperallometric Fecundity

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ontogenetic-Growth-Model---Intake-Rate-&amp;-Hyperallometric-Fecundity" data-toc-modified-id="Ontogenetic-Growth-Model---Intake-Rate-&amp;-Hyperallometric-Fecundity-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ontogenetic Growth Model - Intake Rate &amp; Hyperallometric Fecundity</a></span><ul class="toc-item"><li><span><a href="#Derivation---Master-Balance-Equation-(West-et-al.,-2001)" data-toc-modified-id="Derivation---Master-Balance-Equation-(West-et-al.,-2001)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Derivation - Master Balance Equation (West <em>et al.</em>, 2001)</a></span><ul class="toc-item"><li><span><a href="#Growth-from-metabolic-energy-inflow" data-toc-modified-id="Growth-from-metabolic-energy-inflow-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Growth from metabolic energy inflow</a></span></li><li><span><a href="#Surplus-is-reduced-by-efficiency-of-use-(ingestion-versus-energy-flow-into-branching-network)" data-toc-modified-id="Surplus-is-reduced-by-efficiency-of-use-(ingestion-versus-energy-flow-into-branching-network)-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Surplus is reduced by efficiency of use (ingestion versus energy flow into branching network)</a></span></li><li><span><a href="#Can-also-introduce-loss-to-reproduction" data-toc-modified-id="Can-also-introduce-loss-to-reproduction-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Can also introduce loss to reproduction</a></span></li><li><span><a href="#Objectives/Thoughts" data-toc-modified-id="Objectives/Thoughts-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Objectives/Thoughts</a></span></li><li><span><a href="#Diego's-Paper" data-toc-modified-id="Diego's-Paper-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Diego's Paper</a></span></li><li><span><a href="#Growth-rate" data-toc-modified-id="Growth-rate-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Growth rate</a></span></li><li><span><a href="#Assimilation/Intake" data-toc-modified-id="Assimilation/Intake-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Assimilation/Intake</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Derivation - Master Balance Equation (West *et al.*, 2001)
# ### Growth from metabolic energy inflow
# * $B$ = incoming rate of energy flow, which is the average resting metabolic rate of the whole organism at time $t$
# * $B_c$ = the metabolic rate of a single cell
# * $E_c$ = the metabolic energy required to create a cell
# * $N_c$ = the total number of cells
# * $\sum\limits_c$ = over all types of tissue, assuming a typical cell as the fundamental unit
# * tells us that dedication to growth **AFTER** metabolism is a fundamental axiom of energy/mass conservation equation
# * growth is equal to surplus energy because assumed that energy is optimally allocated to growth after miscellaneous costs
# \begin{align*}
#     B &= \sum_c \Bigg[N_{c}B_{c} + E_{c}\frac{dN_{c}}{dt}\Bigg] \\
#     B &= N_{c}B_{c} + E_{c}\frac{dN_{c}}{dt} \\
#     \frac{dN_{c}}{dt} &= \frac{B - N_{c}B_{c}}{E_{c}} = \frac{\text{Surplus energy}}{\text{Cost of creating single cell}} \\
#     &= \text{multiply by mass of single cell} \\
#     \Bigg(\frac{dN_{c}}{dt}\Bigg)m_c &= \Bigg(\frac{B - N_{c}B_{c}}{E_{c}}\Bigg)m_c \\
#     \frac{dm}{dt} &= \Bigg(\frac{Bm_c}{E_c}\Bigg) - \Bigg(\frac{N_{c}m_{c}B_{c}}{E_c}\Bigg) \\
#     \frac{dm}{dt} &= \Bigg(\frac{Bm_c}{E_c}\Bigg) - \Bigg(\frac{m_{tot}B_{c}}{E_c}\Bigg) \\
#     \frac{dm}{dt} &= \Bigg(\frac{m_c}{E_c}\Bigg)B - \Bigg(\frac{B_{c}}{E_c}\Bigg)m_{tot} \\
#     \text{sub } B &= B_{0}m^{3/4}  \\
#     \frac{dm}{dt} &= \frac{m_c}{E_c}B_{0}m^{3/4} - \frac{B_{c}}{E_c}m_{tot} \\
#     \text{sub } a &= \frac{m_c}{E_c}B_{0}  \\
#     b &= \frac{B_{c}}{E_c} \\
#     \frac{dm}{dt} &= am^{3/4} - bm \\
# \end{align*}
# ### Surplus is reduced by efficiency of use (ingestion versus energy flow into branching network)
# * $I$ = consumption rate $\big(\frac{mass}{time}\big)$
# * $t_I$ = "characteristic" time period for "sufficient" energy gain
# * $t_I << t_{growth}$
# * Need to tackle this time period, we know $t \propto \kappa m^{\gamma}$ i.e. bigger things can spend longer foraging, thus intake more (absolute not relative)
# * But their digestion is then slower
# * reasonable bounding of digestion times?
# * Timescale at level of digestion is different to timescale of growth
# * You may pass a threshold where you are digesting at maximum rate meaning that you are limited to $3/4$ exponent because limited by fractal dimension of capillary network
# * Intake is the amount of energy flowing through your network and to your cells
# * Intake rate cannot be optimised since it's what the environment gives you, then you can decide on your reproductive output - timing and amount
# \begin{align*}
#     I_{tot} &= \int_{t_{start}}^{t_{end}} I dt \\
#     \frac{m_c}{E_c}B_{0}m^{3/4} &= am^{3/4} \\
#     \frac{am^{3/4}}{m} &= am^{\frac{3}{4} - 1} \\
#     \frac{am^{3/4}}{m} &= am^{-\frac{1}{4}} \\
#     I_{tot}\epsilon\Big(am^{-\frac{1}{4}}\Big) \\
# \end{align*}
#
# * Intake rate
#     * Intake rate scales with mass i.e. $I \propto m^{\gamma}$ or $I = I_{0}m^{\gamma}$
#     * Total intake is intake rate * time i.e. $\frac{\text{mass}}{\text{time}}\cdot\text{time}$
#     * time spent intaking/foraging also scales with mass i.e. $t \propto m^{\psi}$ or $t = t_{0}m^{\psi}$
# \begin{align*}
#     \text{Intake rate} &= I_{0}m^{\gamma} \\
#     \text{Total intake} &= I_{0}m^{\gamma}*t \\
#     \text{Total intake} &= I_{0}m^{\gamma}t_{0}m^{\psi} \\
#     \text{Total intake, } I_{tot} &= I_{0}t_{0}m^{\gamma + \psi}
# \end{align*}
# * Which in effect is "mass-specific intrinsic distribution of resources"
# ### Can also introduce loss to reproduction
# \begin{align*}
#     \frac{dm}{dt} &= I_{tot}\epsilon\Big(am^{-\frac{1}{4}}\Big) - bm - cm^{\rho} \\
#     \frac{dm}{dt} &= I_{0}t_{0}m^{\gamma + \psi}\epsilon\Big(am^{-\frac{1}{4}}\Big) - bm - cm^{\rho} \\
#     \frac{dm}{dt} &= I_{0}t_{0}\epsilon am^{\gamma + \psi}\Big(m^{-\frac{1}{4}}\Big) - bm - cm^{\rho} \\
#     \text{let } a_0 &= I_{0}t_{0}\epsilon a \\
#     \frac{dm}{dt} &= a_{0}m^{\gamma + \psi -\frac{1}{4}} - bm - cm^{\rho} \\
# \end{align*}
# ### Objectives/Thoughts
# * What data to we have?
#     * intake rate
#     * digestion rate
#     * individual growth rate
# * We want to plug into
#     * intake rate data
# * Fit across whole range of fish
# * Parameterisation
# * What are we optimising
# * Shrinking fish -they would never grow to a size where they would then have to shrink

# %% [markdown]
# ### Life history assumption is that we are always maximising lifetime reproductive output
# \begin{align*}
#     \text{MAXIMISE} \int_{\alpha}^{\infty}L_{x}M_{x} dt \\
#     m_{x} &= cm^{\rho}
# \end{align*}

# %% [markdown]
# ### Diego's Paper
# * if assimilation (or total intake) is a function of mass: $A(m)$
# * $E_c =$ combustion energy of biomass
# * $B_{tot} =$ total (i.e. field) metabolic rate = $\sum B_{rest} + B_{act}$ which sustains locomotion, feeding and other activities
# * $B_{tot} = fB_{rest}$
# * $f$ = dimensionless parameter "activity scope" or "factorial aerobic scope" - ratio of resting to active metabolism
#
# ### Growth rate
# \begin{align*}
#     \frac{dm}{dt} &= \frac{B_r}{E_m}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg] \\
#     \frac{dm}{dt} &= \frac{B_{0}(T)}{E_m}m^{\alpha}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg]
# \end{align*}
#
# ### Assimilation/Intake
# \begin{align*}
#     A(m) &= B_{tot} + E_{c}\frac{dm}{dt} = fB_{r} + E_{c}\frac{B_{r}}{E_{m}}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg] \\
#     A(m) &= B_{0}(T)m^{\alpha}\Bigg[f+\frac{E_{c}}{E_{m}}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg]\Bigg] \\
#     \text{ignore T for now} \\
#     \text{substitute } I_{tot}\epsilon \text{ for assimilation} \\
#     I_{tot}\epsilon &= B_{0}(T)m^{\alpha}\Bigg[f+\frac{E_{c}}{E_{m}}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg]\Bigg] \\
#     \text{sub in  } \frac{dm}{dt} &= \frac{B_{0}(T)}{E_m}m^{\alpha}\Bigg[1 - \Big(\frac{m}{M}\Big)^{1-\alpha}\Bigg] \\
#     I_{tot}\epsilon &= B_{0}m^{\alpha}f + E_{c}\frac{dm}{dt} \\
#     \frac{dm}{dt} &= \frac{I_{tot}\epsilon-B_{0}m^{\alpha}f}{E_{c}} \\
#     \frac{dm}{dt} &= \frac{a_{0}m^{\gamma + \psi -\frac{1}{4}}-B_{0}m^{\alpha}f}{E_{c}} \\
#     \text{substitute } a_0 &= I_{0}t_{0}\epsilon a \\
#     \frac{dm}{dt} &= \frac{a_0m^{\gamma + \psi -\frac{1}{4}} a-B_{0}m^{\alpha}f}{E_{c}}
# \end{align*}

# %%
#####################################################
#################### Guinea Pig #####################
#####################################################

# Imports
import scipy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from scipy.stats import multivariate_normal
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# no need to include a Lt ODE since we already have a closed form solution to this ODE - 
# pointless using ode.int to integrate it numerically

# Define L(t)
def L(t):
    return sc.exp(-mu*t)

def dCR_dt(growth_values, t, a, b, c, rho, alpha):                 
    """ Takes model parameters and populates array
    based on model calculations"""
    m = growth_values[0]
    r = growth_values[1]
    Q = L(t - alpha)
    if t < alpha:            # juvenile stage
        dmdt = a*(m**0.75) - b*m
        dRdt = 0
    elif t >= alpha:          # mature adult stage
        dmdt = a*(m**0.75) - b*m - c*(m**rho)
        dRdt = Q*c * m**rho      # because lifetime R is the integral of RHS, so ODE is RHS with no integrand
    if m+dmdt < 0:
        dmdt = -m
    return sc.array([dmdt, dRdt])




# Define initial conditions for integration - these are used throughout whole notebook to avoid hard-coding
hypothetical_starting_mass = 5
hypothetical_asymptotic_mass = 840

hypothetical_starting_reproduction = c*hypothetical_starting_mass**rho
mr0 = sc.array([hypothetical_starting_mass, hypothetical_starting_reproduction])

# Define the time vector
t = np.arange(0, 800, 1)

# Populate arrays

a = 0.2  
b = a/(hypothetical_asymptotic_mass**0.25)     # rearrange eq. 6 to find b in terms of a
c = 0.001
rho = 1




# set parameters
resolution = 15
rho_values = np.linspace(0.75,1.5,resolution)
alpha_values = np.linspace(50,800,resolution)
mu = 0.01

# Integration - loop through all maturation ages within all exponent values
# cumRepro = np.ones((resolution,resolution))
cumRepro = np.ones((resolution,resolution))
 
ax = plt.gca()
for j, alpha in enumerate(alpha_values):
    alpha = alpha_values[j]
    color = next(ax._get_lines.prop_cycler)['color'] # keep color the same for both growth curve and repro curve with same rho value
    for i, rho in enumerate(rho_values):
        rho = rho_values[i]
        lifetime_repro, infodict = integrate.odeint(dCR_dt, mr0, t, args = (a,b,c,rho,alpha),full_output = True)
#         plt.vlines(alpha, color='grey',linestyle='--', linewidth=1, ymin=0, ymax=lifetime_repro[alpha][0])
        plt.plot(t, lifetime_repro[:,0], color = color, label = rho_values[i])
        plt.plot(t, lifetime_repro[:,1], color = color) # label = 'Mass with Time')
        cumRepro[i,j] = lifetime_repro[-1][1] # only want repro so print second element of scipy array

        
# Plot growth curves under different regimes
plt.grid()
plt.plot(t, 800*L(t))
# plt.legend(loc='best', title=r'$\rho$ = ')
plt.xlabel('Time (Days)')
ax.set_xlim([0,len(t)])
ax.set_ylim([0,hypothetical_asymptotic_mass+100])
plt.rcParams['figure.figsize'] = [8,5]
plt.ylabel('Size (g)')
plt.title("Lifetime Growth at Different Reproductive Allometry Exponents \n {} \n West et al. Guinea pig parameters".format(r'$dm/dt = am^x - bm - cm^{\rho}$'))
plt.savefig('../Results/growth_curve_rho.pdf', bbox_inches='tight')
plt.show()

# %%
####################################################################
#################### ATLANTIC COD GADUS MORHUA #####################
####################################################################


# Define L(t)
def L(t):
    return sc.exp(-mu*t)

def dCR_dt(growth_values, t, a, b, c, rho, alpha):                 
    """ Takes model parameters and populates array
    based on model calculations"""
    m = growth_values[0]
    r = growth_values[1]
    Q = L(t - alpha)
    if t < alpha:            # juvenile stage
        dmdt = a*(m**0.75) - b*m
        dRdt = 0
    elif t >= alpha:          # mature adult stage
        dmdt = a*(m**0.75) - b*m - c*(m**rho)
        dRdt = Q*c * m**rho      # because lifetime R is the integral of RHS, so ODE is RHS with no integrand
#     if m+dmdt < 0:
#         dmdt = -m
    return np.array([dmdt, dRdt])#, dtype=np.float128)

# Define initial conditions for integration - these are used throughout whole notebook to avoid hard-coding 
hypothetical_starting_mass = 0.1
hypothetical_asymptotic_mass = 25000

hypothetical_starting_reproduction = c*hypothetical_starting_mass**rho
mr0 = sc.array([hypothetical_starting_mass, hypothetical_starting_reproduction])

# Define the time vector
t = np.arange(0, 12*365, 1)

# Populate arrays

a = 0.017
b = a/(hypothetical_asymptotic_mass**0.25)     # rearrange eq. 6 to find b in terms of a
c = 0.008 # West et al. assume 0.1 from Peters

# set parameters
resolution = 20
rho_values = np.linspace(0.75,1.5,resolution)
alpha_values = np.linspace(50,15*365,resolution) # maturing up to 10 yrs old
mu = 0.01

# Integration - loop through all maturation ages within all exponent values

cumRepro = np.ones((resolution,resolution))
 
ax = plt.gca()
for j, alpha in enumerate(alpha_values):
    alpha = alpha_values[j]
    color = next(ax._get_lines.prop_cycler)['color'] # keep color the same for both growth curve and repro curve with same rho value
    for i, rho in enumerate(rho_values):
        hypothetical_starting_reproduction = c*hypothetical_starting_mass**rho
        rho = rho_values[i]
        lifetime_repro, infodict = integrate.odeint(dCR_dt, mr0, t, args = (a,b,c,rho,alpha),full_output = True)
#         plt.vlines(alpha, color='grey',linestyle='--', linewidth=1, ymin=0, ymax=lifetime_repro[alpha][0])
        plt.plot(t, lifetime_repro[:,0], color = color, label = rho_values[i])
        plt.plot(t, lifetime_repro[:,1], color = color) # label = 'Mass with Time')
        cumRepro[i,j] = lifetime_repro[-2,1] # only want repro so print second element of scipy array


# Plot growth curves under different regimes
plt.grid()
# plt.plot(t, 4000*L(t), linestyle=':')
# plt.legend(loc='best', title=r'$\rho$ = ')
plt.xlabel('Time (Days)')
ax.set_xlim([0,len(t)])
ax.set_ylim([-0,1000]) # whitespace because indeterminate so never reach asymptote
plt.rcParams['figure.figsize'] = [8,5]
plt.ylabel('Size (g)')
plt.title("Lifetime Growth at Different Reproductive Allometry Exponents for \n Atlantic Cod (Gadus morhua) \n {}".format(r'$dm/dt = am^x - bm - cm^{\rho}$'))
# plt.annotate(' a = {} \n b = {} \n c = {} \n M = {}'.format(str(a), str(b), str(c), str(hypothetical_asymptotic_mass)), xy=(0,0), xytext=(500,3000))
plt.savefig('../Results/growth_curves_Atlantic_Cod.pdf', bbox_inches='tight')
plt.show()

# %%
L(12*365)
print(alpha_values[-10])
# Out:
# 2905.263157894737

# %%
np.set_printoptions(suppress=True)
i,j = -1,-10
alpha = alpha_values[j]
print(alpha)
hypothetical_starting_mass = 3990.58619164
hypothetical_starting_reproduction = 0.00025298
mr0 = sc.array([hypothetical_starting_mass, hypothetical_starting_reproduction])

rho = rho_values[i]
lifetime_repro, infodict = integrate.odeint(dCR_dt, mr0, t, args = (a,b,c,rho,alpha),full_output = True)
lifetime_repro
# Out:
# 2905.263157894737
# array([[ 3990.58619164,     0.00025298],
#        [ 3993.72692395,     0.00025298],
#        [ 3996.86844752,     0.00025298],
#        [ 4000.01076158,     0.00025298],
#        [ 4003.15386525,     0.00025298],
#        [ 4006.29775807,     0.00025298],
#        [ 4009.44243916,     0.00025298],
#        [ 4012.58790767,     0.00025298],
#        [ 4015.73416279,     0.00025298],
#        [ 4018.88120368,     0.00025298],
#        [ 4022.02902951,     0.00025298],
#        [ 4025.17763945,     0.00025298],
#        [ 4028.32703267,     0.00025298],
#        [ 4031.47720834,     0.00025298],
#        [ 4034.62816563,     0.00025298],
#        [ 4037.7799037 ,     0.00025298],
#        [ 4040.93242173,     0.00025298],
#        [ 4044.08571905,     0.00025298],
#        [ 4047.23979495,     0.00025298],
#        [ 4050.39464864,     0.00025298],
#        [ 4053.55027934,     0.00025298],
#        [ 4056.70668624,     0.00025298],
# ...

# %%
print(alpha, rho)

len(t)
# Out:
# 2905.263157894737 1.5
# 4380

# %%
lifetime_repro[4201]
# Out:
# array([nan, nan])

# %%
np.where(np.isnan(lifetime_repro))
# Out:
# (array([2778, 2778, 2779, 2779, 2780, 2780, 2781, 2781, 2782, 2782, 2783,
#         2783, 2784, 2784, 2785, 2785, 2786, 2786, 2787, 2787, 2788, 2788,
#         2789, 2789, 2790, 2790, 2791, 2791, 2792, 2792, 2793, 2793, 2794,
#         2794, 2795, 2795, 2796, 2796, 2797, 2797, 2798, 2798, 2799, 2799,
#         2800, 2800, 2801, 2801, 2802, 2802, 2803, 2803, 2804, 2804, 2805,
#         2805, 2806, 2806, 2807, 2807, 2808, 2808, 2809, 2809, 2810, 2810,
#         2811, 2811, 2812, 2812, 2813, 2813, 2814, 2814, 2815, 2815, 2816,
#         2816, 2817, 2817, 2818, 2818, 2819, 2819, 2820, 2820, 2821, 2821,
#         2822, 2822, 2823, 2823, 2824, 2824, 2825, 2825, 2826, 2826, 2827,
#         2827, 2828, 2828, 2829, 2829, 2830, 2830, 2831, 2831, 2832, 2832,
#         2833, 2833, 2834, 2834, 2835, 2835, 2836, 2836, 2837, 2837, 2838,
#         2838, 2839, 2839, 2840, 2840, 2841, 2841, 2842, 2842, 2843, 2843,
#         2844, 2844, 2845, 2845, 2846, 2846, 2847, 2847, 2848, 2848, 2849,
# ...

# %%
plt.plot(t,lifetime_repro)

# %%
# 3D PLOT: (Fitness Surface)
x,y = np.meshgrid(rho_values, alpha_values) # generates a 25x25 grid for rho and alpha respectively (ie. all the x values and all the y values)
z = cumRepro.transpose() # cartesian coordinates vs numpy matrix

from mpl_toolkits.mplot3d import Axes3D

# Generate plot
fig = plt.figure()
ax = fig.gca(projection='3d')

# TeX font
# fig.rc('text', usetex=True)
# fig.rc('font', family='serif')

# Rotation angle
# Get current rotation angle
# print(ax.azim)
# Set rotation angle to 30 degrees
ax.view_init(azim=60)
surf = ax.plot_surface(x, y, z, cmap=cm.hot,linewidth=0, antialiased=False)

# Axes labels
ax.set_xlabel('ATR exponent, {}'.format(r'$\rho$'), labelpad = 15)
ax.set_ylabel('Age at Maturation \n (days), {}'.format(r'$\alpha$'), labelpad = 15)
ax.set_zlabel('Lifetime Reproduction, {}'.format(r'$R$'))


# Add a color bar which maps values to colors.
# plt.rcParams['figure.figsize'] = [5,5] # change plot size
#fig.colorbar(surf, shrink=0.5, aspect=20)#, orientation="horizontal")
plt.colorbar(surf,fraction=0.046, pad=0.07, orientation="vertical")
plt.savefig('../Results/fitness_surface_Gadus_morhua.pdf', bbox_inches='tight')
plt.show()
print(z)
# Out:
# [[1.80495332e+02 2.38587587e+02 3.10874317e+02 3.96694674e+02
#   4.91788243e+02 5.87091923e+02 6.69525883e+02 7.25963194e+02
#   7.48829668e+02 7.39145739e+02 7.04696782e+02 6.55553205e+02
#   6.00459490e+02 5.45418794e+02 4.93843139e+02 4.47282081e+02
#   4.06147235e+02 3.70240188e+02 3.39082662e+02 3.12103123e+02]
#  [8.48808309e+02 1.19994766e+03 1.67625886e+03 2.30154791e+03
#   3.08461158e+03 4.00335486e+03 4.99333532e+03 5.95570928e+03
#   6.79027752e+03 7.43409554e+03 7.87683769e+03 8.14756051e+03
#   8.29096603e+03 8.34978439e+03 8.35722956e+03 8.33619828e+03
#              nan            nan            nan            nan]
#  [1.28291517e+03 1.85714876e+03 2.65950756e+03 3.74845305e+03
#   5.16512849e+03 6.90265203e+03 8.87528882e+03 1.09157311e+04
#   1.28225274e+04 1.44356193e+04 1.56846855e+04 1.65836562e+04
#   1.71938280e+04 1.75883991e+04            nan            nan
#              nan            nan            nan            nan]
# ...

# %%
####################################################################
############### SOCKEYE SALMON (Oncorhynchus nerka) ################
####################################################################

# Define initial conditions for integration - these are used throughout whole notebook to avoid hard-coding 
hypothetical_starting_mass = 0.01
hypothetical_asymptotic_mass = 240 # Suspect that West et al made a typo?

hypothetical_starting_reproduction = c*hypothetical_starting_mass**rho
mr0 = sc.array([hypothetical_starting_mass, hypothetical_starting_reproduction])

# Define the time vector
t = np.arange(0, 1260, 1)

# Populate arrays

a = 0.026
b = a/(hypothetical_asymptotic_mass**0.25)     # rearrange eq. 6 to find b in terms of a
c = 0.008 # West et al. assume 0.1 from Peters

# set parameters
resolution = 10
rho_values = np.linspace(0.75,1.5,resolution)
alpha_values = np.linspace(50,1000,resolution) # maturing up to 10 yrs old
mu = 0.01

# Integration - loop through all maturation ages within all exponent values

cumRepro = np.ones((resolution,resolution))
 
ax = plt.gca()
for j, alpha in enumerate(alpha_values):
    alpha = alpha_values[j]
    color = next(ax._get_lines.prop_cycler)['color'] # keep color the same for both growth curve and repro curve with same rho value
    for i, rho in enumerate(rho_values):
        hypothetical_starting_reproduction = c*hypothetical_starting_mass**rho
        rho = rho_values[i]
        lifetime_repro, infodict = integrate.odeint(dCR_dt, mr0, t, args = (a,b,c,rho,alpha),full_output = True)
#         plt.vlines(alpha, color='grey',linestyle='--', linewidth=1, ymin=0, ymax=lifetime_repro[alpha][0])
        plt.plot(t, lifetime_repro[:,0], color = color, label = rho_values[i])
        plt.plot(t, lifetime_repro[:,1], color = color) # label = 'Mass with Time')
        cumRepro[i,j] = lifetime_repro[-1][1] # only want repro so print second element of scipy array

        
# Plot growth curves under different regimes
plt.grid()
# plt.plot(t, 4000*L(t), linestyle=':')
# plt.legend(loc='best', title=r'$\rho$ = ')
plt.xlabel('Time (Days)')
ax.set_xlim([0,len(t)])
ax.set_ylim([0,hypothetical_asymptotic_mass]) # whitespace because indeterminate so never reach asymptote
plt.rcParams['figure.figsize'] = [8,5]
plt.ylabel('Size (g)')
plt.title("Lifetime Growth at Different Reproductive Allometry Exponents for \n Sockeye Salmon (Oncorhynchus nerka) \n {}".format(r'$dm/dt = am^x - bm - cm^{\rho}$'))
plt.annotate(' a = {} \n b = {} \n c = {} \n M = {}'.format(str(a), str(b), str(c), str(hypothetical_asymptotic_mass)), xy=(0,0), xytext=(500,3000))
plt.savefig('../Results/growth_curves_Oncorhynchus_nerka.pdf', bbox_inches='tight')
plt.show()

# %%
# 3D PLOT: (Fitness Surface)
x,y = np.meshgrid(rho_values, alpha_values) # generates a 25x25 grid for rho and alpha respectively (ie. all the x values and all the y values)
z = cumRepro.transpose() # cartesian coordinates vs numpy matrix

from mpl_toolkits.mplot3d import Axes3D

# Generate plot
fig = plt.figure()
ax = fig.gca(projection='3d')

# TeX font
# fig.rc('text', usetex=True)
# fig.rc('font', family='serif')

# Rotation angle
# Get current rotation angle
# print(ax.azim)
# Set rotation angle to 30 degrees
ax.view_init(azim=60)
surf = ax.plot_surface(x, y, z, cmap=cm.hot,linewidth=0, antialiased=False)

# Axes labels
ax.set_xlabel('ATR exponent, {}'.format(r'$\rho$'), labelpad = 15)
ax.set_ylabel('Age at Maturation \n (days), {}'.format(r'$\alpha$'), labelpad = 15)
ax.set_zlabel('Lifetime Reproduction, {}'.format(r'$R$'))


# Add a color bar which maps values to colors.
# plt.rcParams['figure.figsize'] = [5,5] # change plot size
#fig.colorbar(surf, shrink=0.5, aspect=20)#, orientation="horizontal")
plt.colorbar(surf,fraction=0.046, pad=0.07, orientation="vertical")
plt.savefig('../Results/optimisation.pdf', bbox_inches='tight')
# plt.show()
